# %% [markdown]
# # matplotlib

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Gráficos de Linha I

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
amount = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
# cria gráfico de linha
plt.plot(years, amount, color = 'blue', marker = 'o', linestyle = 'solid')

# titulo
plt.title("Amount")

# label do eixo y
plt.ylabel("Bilhoes $")

plt.show()

# %% [markdown]
# ##### Gráficos de Barra

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# adiciona-se 0.5 às coordenadas à esquerda para que cada barra seja centralizada
xs = [i + 0.5 for i, _ in enumerate(movies)]

# barras com as coordenadas x à esquerda [xs], alturas [num_oscars]
plt.bar(xs, num_oscars)

plt.ylabel("# de premiações")
plt.title("Filmes")

# nomeia eixo x com nomes de filmes na barra central
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)

plt.show()

# %% [markdown]
# ##### Histogramas

# %%
from collections import Counter

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)

# %%
plt.bar([x for x in histogram.keys()],  
       histogram.values(),                  # ajusta a altura das barras
       8)                                   # largura da barra = 8

plt.axis([-5, 105, 0, 5])                   # intervalos dos eixos x e y

plt.xticks([10 * i for i in range(11)])       # rótulos de x
plt.xlabel("Decil")
plt.ylabel("# Alunos")
plt.title("Distribuição das Notas do Teste")
plt.show()

# %% [markdown]
# ##### Gráficos de Linha II

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
# pode-se fazer multiplas chamadas para plt.plot
# assim teremos múltiplas séries no mesmo gráfico

plt.plot(xs, variance, 'g-', label='variance')       # linha verde sólida
plt.plot(xs, bias_squared, 'r-.', label='bias^2')    # linha com linha e ponto (vermelho)
plt.plot(xs, total_error, 'b:', label='total error') # linha pontilhada azul

plt.legend(loc = 9) # "top center"
plt.xlabel("Complexidade do Modelo")
plt.title("Compromisso entre Polarização e Variância")
plt.show()
